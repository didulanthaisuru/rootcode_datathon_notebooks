# %%
# ===============================
# 1️⃣ IMPORTS
# ===============================
import pandas as pd
import numpy as np
from prophet import Prophet
from sklearn.metrics import mean_absolute_error
import optuna
import matplotlib.pyplot as plt
import seaborn as sns

# ===============================
# 2️⃣ LOAD DATA
# ===============================
df = pd.read_csv('final_df_binary.csv', parse_dates=['date'])
df['is_working_day'] = ((df['employees_on_duty']>0)*1)

train_df = df[df['date'] < '2024-01-01'].copy()
test_df  = df[df['date'].dt.year == 2024].copy()

# ===============================
# 3️⃣ DEFINE OPTUNA OBJECTIVE
# ===============================
# ===============================
# 3️⃣ DEFINE OPTUNA OBJECTIVE (UPDATED)
# ===============================
def prophet_objective(trial, df_section):
    # Hyperparameter search space
    cps = trial.suggest_float("changepoint_prior_scale", 0.001, 0.5, log=True)
    sps = trial.suggest_float("seasonality_prior_scale", 0.01, 40, log=True)
    hps = trial.suggest_float("holidays_prior_scale", 0.01, 40, log=True)
    cpr = trial.suggest_float("changepoint_range", 0.01, 0.99)
    seasonality_mode = trial.suggest_categorical("seasonality_mode", ["additive", "multiplicative"])
    growth = trial.suggest_categorical("growth", ["linear", "logistic"])
    fourier_m = trial.suggest_int("fourier_order_monthly", 3, 40)
    fourier_q = trial.suggest_int("fourier_order_quarterly", 3, 40)

    model = Prophet(
        yearly_seasonality=True,
        weekly_seasonality=False,
        daily_seasonality=False,
        changepoint_prior_scale=cps,
        seasonality_prior_scale=sps,
        holidays_prior_scale=hps,
        changepoint_range=cpr,
        seasonality_mode=seasonality_mode,
        growth=growth
    )
    model.add_seasonality(name='monthly', period=30.5, fourier_order=fourier_m)
    model.add_seasonality(name='quarterly', period=91.25, fourier_order=fourier_q)
    model.add_regressor('is_holiday')
    model.add_regressor('is_weekend')

    df_prophet = df_section[['date','total_task_time_minutes','is_holiday','is_weekend']].rename(
        columns={'date':'ds','total_task_time_minutes':'y'}
    )

    # Logistic growth requires 'cap' column
    if growth == "logistic":
        df_prophet["cap"] = df_prophet["y"].max() * 1.2

    model.fit(df_prophet)
    forecast = model.predict(df_prophet[['ds','is_holiday','is_weekend'] + (["cap"] if growth=="logistic" else [])])
    forecast['yhat'] = forecast['yhat'].clip(lower=0)

    mae = mean_absolute_error(df_prophet['y'], forecast['yhat'])
    return mae


# ===============================
# 4️⃣ FORECAST LOOP WITH OPTUNA
# ===============================
task_forecasts = {}
section_stats = []

for section in train_df['section_id'].unique():
    df_section = train_df[(train_df['section_id']==section) & (train_df['is_working_day']==1)]
    df_test_sec = test_df[(test_df['section_id']==section) & (test_df['is_working_day']==1)]
    
    if len(df_section)<50 or len(df_test_sec)==0:
        print(f"Skipping section {section}")
        continue
    
    # Section statistics
    stats = {
        'section_id': section,
        'mean': df_section['total_task_time_minutes'].mean(),
        'median': df_section['total_task_time_minutes'].median(),
        'mode': df_section['total_task_time_minutes'].mode().values[0],
        'max': df_section['total_task_time_minutes'].max(),
        'min': df_section['total_task_time_minutes'].min(),
        'std': df_section['total_task_time_minutes'].std()
    }
    section_stats.append(stats)
    
    # OPTUNA study
    study = optuna.create_study(direction='minimize')
    study.optimize(lambda trial: prophet_objective(trial, df_section), n_trials=25)
    
    best_params = study.best_params
    print(f"{section}: Best params {best_params}, Best MAE {study.best_value:.2f}")
    
    # Fit best model
    best_model = Prophet(
        yearly_seasonality=True,
        weekly_seasonality=False,
        daily_seasonality=False,
        changepoint_prior_scale=best_params['changepoint_prior_scale'],
        seasonality_prior_scale=best_params['seasonality_prior_scale']
    )
    best_model.add_seasonality(name='monthly', period=30.5, fourier_order=best_params['fourier_order_monthly'])
    best_model.add_seasonality(name='quarterly', period=91.25, fourier_order=best_params['fourier_order_quarterly'])
    best_model.add_regressor('is_holiday')
    best_model.add_regressor('is_weekend')
    
    df_prophet = df_section[['date','total_task_time_minutes','is_holiday','is_weekend']].rename(
        columns={'date':'ds','total_task_time_minutes':'y'})
    best_model.fit(df_prophet)
    
    # Forecast 2024
    future_2024 = df_test_sec[['date','is_holiday','is_weekend']].rename(columns={'date':'ds'})
    forecast_2024 = best_model.predict(future_2024)
    forecast_2024['yhat'] = forecast_2024['yhat'].clip(lower=0)
    
    task_forecasts[section] = pd.DataFrame({
        'date': df_test_sec['date'],
        'section_id': df_test_sec['section_id'],
        'is_weekend': df_test_sec['is_weekend'],
        'is_holiday': df_test_sec['is_holiday'],
        'actual_task_minutes': df_test_sec['total_task_time_minutes'],
        'predicted_task_minutes': forecast_2024['yhat'].values,
    })

# ===============================
# 5️⃣ COMBINE FORECASTS
# ===============================
combined_forecast = pd.concat(task_forecasts.values(), axis=0)
combined_forecast['error'] = combined_forecast['actual_task_minutes'] - combined_forecast['predicted_task_minutes']

# Section-wise MAE
section_errors = combined_forecast.groupby('section_id')['error'].apply(lambda x: np.mean(np.abs(x))).reset_index()
section_errors.rename(columns={'error':'avg_abs_error'}, inplace=True)

section_stats_df = pd.DataFrame(section_stats)
section_summary = section_stats_df.merge(section_errors, on='section_id')

# ===============================
# 6️⃣ VISUALIZATIONS SECTION WISE
# ===============================
for section in combined_forecast['section_id'].unique():
    sec_df = combined_forecast[combined_forecast['section_id']==section]
    
    plt.figure(figsize=(10,6))
    sns.scatterplot(
        x='actual_task_minutes', y='predicted_task_minutes', 
        hue='is_weekend', style='is_holiday', data=sec_df, alpha=0.7
    )
    plt.plot([0, sec_df['actual_task_minutes'].max()],
             [0, sec_df['actual_task_minutes'].max()], 'r--', linewidth=2)
    plt.title(f'Section {section} - Actual vs Predicted')
    plt.xlabel('Actual Task Minutes')
    plt.ylabel('Predicted Task Minutes')
    plt.legend(title='Weekend / Holiday')
    plt.show()
# Out:
# [I 2025-08-23 01:00:55,894] A new study created in memory with name: no-name-517c5c7a-76d1-4abe-9214-20aedc4954a0
# 01:00:57 - cmdstanpy - INFO - Chain [1] start processing
# 01:00:57 - cmdstanpy - INFO - Chain [1] done processing
# [I 2025-08-23 01:00:58,036] Trial 0 finished with value: 406.2051653094946 and parameters: {'changepoint_prior_scale': 0.0043619441231235205, 'seasonality_prior_scale': 0.06725631826825733, 'holidays_prior_scale': 0.0793598469391382, 'changepoint_range': 0.16172750129321384, 'seasonality_mode': 'multiplicative', 'growth': 'logistic', 'fourier_order_monthly': 19, 'fourier_order_quarterly': 32}. Best is trial 0 with value: 406.2051653094946.
# 01:00:58 - cmdstanpy - INFO - Chain [1] start processing
# 01:00:58 - cmdstanpy - INFO - Chain [1] done processing
# ...
