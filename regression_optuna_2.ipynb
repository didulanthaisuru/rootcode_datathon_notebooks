# %%
# ===============================
# 🔧 HUBER REGRESSION HYPERPARAMETER TUNING
# Separate file for optimizing HuberRegressor parameters
# ===============================

import pandas as pd
import numpy as np
from sklearn.linear_model import HuberRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from sklearn.model_selection import cross_val_score, KFold
import optuna
import warnings
warnings.filterwarnings('ignore')

print("🔧 HUBER REGRESSION HYPERPARAMETER TUNING")
print("=" * 60)

# ===============================
# 📂 LOAD DATA
# ===============================
print("📂 LOADING DATA...")
df = pd.read_csv('final_df_binary.csv')
df['date'] = pd.to_datetime(df['date'])

# Feature engineering
df['year'] = df['date'].dt.year
df['is_working_day'] = ((df['is_holiday'] == 0) & (df['is_weekend'] == 0)).astype(int)

# Use training data only (2021-2023)
train_data = df[df['year'] <= 2023].copy()
working_train = train_data[train_data['is_working_day'] == 1]

print(f"✅ Data loaded: {len(working_train):,} working day records")
print(f"📊 Sections: {working_train['section_id'].nunique()}")

# ===============================
# 🎯 HUBER REGRESSION TUNING FUNCTION
# ===============================
def tune_huber_regression(section_data, section_id, n_trials=100):
    """
    Tune HuberRegressor hyperparameters for a specific section
    
    Parameters to tune:
    - epsilon: Robustness parameter (1.0 - 2.0)
    - alpha: Regularization strength (1e-6 - 1e-1)
    - max_iter: Maximum iterations (100 - 2000)
    - fit_intercept: Whether to fit intercept (True/False)
    """
    
    print(f"\n🔧 Tuning HuberRegressor for {section_id}")
    print(f"   Training samples: {len(section_data)}")
    
    # Prepare data
    X = section_data[['total_task_time_minutes']].values
    y = section_data['employees_on_duty'].values
    
    def objective(trial):
        # Hyperparameters to tune
        epsilon = trial.suggest_float('epsilon', 1.0, 2.5, step=0.05)
        alpha = trial.suggest_float('alpha', 1e-6, 1e-1, log=True)
        max_iter = trial.suggest_int('max_iter', 100, 2000, step=50)
        fit_intercept = trial.suggest_categorical('fit_intercept', [True, False])
        
        # Create model
        model = HuberRegressor(
            epsilon=epsilon,
            alpha=alpha,
            max_iter=max_iter,
            fit_intercept=fit_intercept,
            warm_start=False
        )
        
        # Cross-validation
        cv = KFold(n_splits=5, shuffle=True, random_state=42)
        
        # Use negative MAE as score (since we want to minimize MAE)
        cv_scores = cross_val_score(model, X, y, cv=cv, scoring='neg_mean_absolute_error', n_jobs=-1)
        
        return -cv_scores.mean()  # Return positive MAE for minimization
    
    # Create study
    study = optuna.create_study(direction='minimize', study_name=f'huber_tuning_{section_id}')
    
    # Optimize
    study.optimize(objective, n_trials=n_trials, show_progress_bar=True)
    
    # Get best parameters
    best_params = study.best_params
    best_score = study.best_value
    
    # Test final model with best parameters
    final_model = HuberRegressor(**best_params)
    final_model.fit(X, y)
    
    # Calculate detailed metrics
    y_pred = final_model.predict(X)
    final_mae = mean_absolute_error(y, y_pred)
    final_rmse = np.sqrt(mean_squared_error(y, y_pred))
    final_r2 = r2_score(y, y_pred)
    
    print(f"   ✅ Best MAE: {best_score:.4f}")
    print(f"   📊 Final metrics - MAE: {final_mae:.4f}, RMSE: {final_rmse:.4f}, R²: {final_r2:.4f}")
    print(f"   🎯 Best params: {best_params}")
    
    return {
        'section_id': section_id,
        'best_params': best_params,
        'cv_mae': best_score,
        'final_mae': final_mae,
        'final_rmse': final_rmse,
        'final_r2': final_r2,
        'training_samples': len(section_data),
        'model': final_model
    }

# ===============================
# 🚀 SECTION-WISE HYPERPARAMETER TUNING
# ===============================
print("\n🚀 STARTING SECTION-WISE TUNING...")

tuning_results = []
optimized_models = {}

sections = working_train['section_id'].unique()

for section in sections:
    section_data = working_train[working_train['section_id'] == section].copy()
    
    # Only tune if we have enough data
    if len(section_data) < 30:
        print(f"\n⚠️  Skipping {section}: Insufficient data ({len(section_data)} samples)")
        continue
    
    try:
        # Tune hyperparameters
        result = tune_huber_regression(section_data, section, n_trials=100)
        tuning_results.append(result)
        optimized_models[section] = result['model']
        
    except Exception as e:
        print(f"   ❌ Error tuning {section}: {str(e)}")
        continue

print(f"\n✅ Tuning completed for {len(tuning_results)} sections")

# ===============================
# 📊 RESULTS ANALYSIS
# ===============================
print("\n📊 TUNING RESULTS ANALYSIS")
print("=" * 60)

# Create results DataFrame
results_df = pd.DataFrame([{
    'Section': r['section_id'],
    'Best_Epsilon': r['best_params']['epsilon'],
    'Best_Alpha': r['best_params']['alpha'],
    'Best_MaxIter': r['best_params']['max_iter'],
    'Fit_Intercept': r['best_params']['fit_intercept'],
    'CV_MAE': r['cv_mae'],
    'Final_MAE': r['final_mae'],
    'Final_RMSE': r['final_rmse'],
    'Final_R2': r['final_r2'],
    'Training_Samples': r['training_samples']
} for r in tuning_results])

print("🎯 DETAILED RESULTS:")
print(results_df.round(4))

# ===============================
# 📈 COMPARISON WITH DEFAULT PARAMETERS
# ===============================
print("\n📈 COMPARISON WITH DEFAULT PARAMETERS")
print("=" * 40)

default_results = []

for section in sections:
    section_data = working_train[working_train['section_id'] == section].copy()
    
    if len(section_data) < 30:
        continue
    
    X = section_data[['total_task_time_minutes']].values
    y = section_data['employees_on_duty'].values
    
    # Default model (your current settings)
    default_model = HuberRegressor(epsilon=1.35)  # Your current default
    default_model.fit(X, y)
    
    y_pred_default = default_model.predict(X)
    default_mae = mean_absolute_error(y, y_pred_default)
    default_r2 = r2_score(y, y_pred_default)
    
    default_results.append({
        'Section': section,
        'Default_MAE': default_mae,
        'Default_R2': default_r2
    })

default_df = pd.DataFrame(default_results)

# Merge with tuned results for comparison
comparison_df = results_df[['Section', 'Final_MAE', 'Final_R2']].merge(
    default_df, on='Section', how='inner'
)

comparison_df['MAE_Improvement'] = comparison_df['Default_MAE'] - comparison_df['Final_MAE']
comparison_df['R2_Improvement'] = comparison_df['Final_R2'] - comparison_df['Default_R2']

print("🆚 TUNED vs DEFAULT COMPARISON:")
print(comparison_df.round(4))

print(f"\n📊 SUMMARY:")
print(f"   Average MAE improvement: {comparison_df['MAE_Improvement'].mean():.4f}")
print(f"   Average R² improvement: {comparison_df['R2_Improvement'].mean():.4f}")
print(f"   Sections with improved MAE: {(comparison_df['MAE_Improvement'] > 0).sum()}/{len(comparison_df)}")
print(f"   Sections with improved R²: {(comparison_df['R2_Improvement'] > 0).sum()}/{len(comparison_df)}")

# ===============================
# 💾 SAVE OPTIMIZED PARAMETERS
# ===============================
print("\n💾 SAVING OPTIMIZED PARAMETERS")
print("=" * 40)

# Create optimized parameters dictionary (for use in main code)
OPTIMIZED_HUBER_PARAMS = {}
for result in tuning_results:
    section_id = result['section_id']
    OPTIMIZED_HUBER_PARAMS[section_id] = result['best_params']

print("🔧 OPTIMIZED HUBER PARAMETERS:")
print("# Copy this to your main code:")
print("OPTIMIZED_HUBER_PARAMS = {")
for section, params in OPTIMIZED_HUBER_PARAMS.items():
    print(f"    '{section}': {params},")
print("}")

# Default parameters for new sections
print(f"\n🎯 RECOMMENDED DEFAULT PARAMETERS:")
avg_epsilon = results_df['Best_Epsilon'].mean()
most_common_intercept = results_df['Fit_Intercept'].mode()[0]
avg_max_iter = int(results_df['Best_MaxIter'].mean())

print(f"DEFAULT_HUBER_PARAMS = {{")
print(f"    'epsilon': {avg_epsilon:.4f},")
print(f"    'alpha': 0.0001,  # Median of log-uniform distribution")
print(f"    'max_iter': {avg_max_iter},")
print(f"    'fit_intercept': {most_common_intercept}")
print(f"}}")

# ===============================
# 💾 SAVE FILES
# ===============================
# Save detailed results
results_df.to_csv('huber_regression_tuning_results.csv', index=False)
comparison_df.to_csv('huber_regression_comparison.csv', index=False)

# Save optimized parameters as JSON for easy loading
import json
with open('optimized_huber_params.json', 'w') as f:
    json.dump(OPTIMIZED_HUBER_PARAMS, f, indent=2)

print(f"\n📁 FILES SAVED:")
print(f"   - huber_regression_tuning_results.csv: Detailed tuning results")
print(f"   - huber_regression_comparison.csv: Tuned vs default comparison")
print(f"   - optimized_huber_params.json: Parameters for main code")

print(f"\n🎉 HUBER REGRESSION TUNING COMPLETED!")
print(f"✅ Tuned {len(tuning_results)} sections successfully")

# ===============================
# 📋 INTEGRATION INSTRUCTIONS
# ===============================
print("\n📋 HOW TO INTEGRATE WITH YOUR MAIN CODE:")
print("=" * 50)
print("1. Copy the OPTIMIZED_HUBER_PARAMS dictionary above")
print("2. In your main code, replace the HuberRegressor creation with:")
print("""
# In Block 3 of your main code:
def get_huber_params(section_id):
    return OPTIMIZED_HUBER_PARAMS.get(section_id, DEFAULT_HUBER_PARAMS)

# Replace your model creation:
for section in working_train['section_id'].unique():
    section_data = working_train[working_train['section_id'] == section]
    if len(section_data) > 30:
        X = section_data[['total_task_time_minutes']].values
        y = section_data['employees_on_duty'].values
        
        # Get optimized parameters
        params = get_huber_params(section)
        
        # Build optimized model
        model = HuberRegressor(**params)
        model.fit(X, y)
        # ... rest of your code
""")

print("\n✅ Ready to boost your regression performance!")
# Out:
# 🔧 HUBER REGRESSION HYPERPARAMETER TUNING
# ============================================================
# 📂 LOADING DATA...
# [I 2025-08-23 08:44:44,199] A new study created in memory with name: huber_tuning_SEC-001
# ✅ Data loaded: 4,362 working day records
# 📊 Sections: 6
#
# 🚀 STARTING SECTION-WISE TUNING...
#
# 🔧 Tuning HuberRegressor for SEC-001
#    Training samples: 727
#   0%|          | 0/100 [00:00<?, ?it/s]
# [I 2025-08-23 08:45:06,883] Trial 90 finished with value: 0.5853366689838173 and parameters: {'epsilon': 1.6, 'alpha': 1.9290466461851505e-06, 'max_iter': 650, 'fit_intercept': False}. Best is trial 81 with value: 0.5435778822090033.
# [I 2025-08-23 08:45:06,956] Trial 91 finished with value: 0.5435778822100618 and parameters: {'epsilon': 2.5, 'alpha': 2.3336503863809616e-06, 'max_iter': 500, 'fit_intercept': True}. Best is trial 81 with value: 0.5435778822090033.
# [I 2025-08-23 08:45:07,055] Trial 92 finished with value: 0.543577882210196 and parameters: {'epsilon': 2.5, 'alpha': 2.3645319037131177e-06, 'max_iter': 450, 'fit_intercept': True}. Best is trial 81 with value: 0.5435778822090033.
# [I 2025-08-23 08:45:07,138] Trial 93 finished with value: 0.5435875860037427 and parameters: {'epsilon': 2.45, 'alpha': 9.742188912035972e-06, 'max_iter': 500, 'fit_intercept': True}. Best is trial 81 with value: 0.5435778822090033.
# [I 2025-08-23 08:45:07,230] Trial 94 finished with value: 0.5435971639125412 and parameters: {'epsilon': 2.4000000000000004, 'alpha': 4.702799368494106e-06, 'max_iter': 550, 'fit_intercept': True}. Best is trial 81 with value: 0.5435778822090033.
# [I 2025-08-23 08:45:07,300] Trial 95 finished with value: 0.5435778822098039 and parameters: {'epsilon': 2.5, 'alpha': 2.641775691803188e-06, 'max_iter': 650, 'fit_intercept': True}. Best is trial 81 with value: 0.5435778822090033.
# [I 2025-08-23 08:45:07,394] Trial 96 finished with value: 0.5435971639132873 and parameters: {'epsilon': 2.4000000000000004, 'alpha': 1.3414382516882968e-06, 'max_iter': 700, 'fit_intercept': True}. Best is trial 81 with value: 0.5435778822090033.
# [I 2025-08-23 08:45:07,477] Trial 97 finished with value: 0.5435875860012926 and parameters: {'epsilon': 2.45, 'alpha': 7.121703662677851e-06, 'max_iter': 1600, 'fit_intercept': True}. Best is trial 81 with value: 0.5435778822090033.
# [I 2025-08-23 08:45:07,600] Trial 98 finished with value: 0.543606811617577 and parameters: {'epsilon': 2.35, 'alpha': 3.2808963290978856e-06, 'max_iter': 750, 'fit_intercept': True}. Best is trial 81 with value: 0.5435778822090033.
# [I 2025-08-23 08:45:07,815] A new study created in memory with name: huber_tuning_SEC-002
# [I 2025-08-23 08:45:07,691] Trial 99 finished with value: 0.543587585994887 and parameters: {'epsilon': 2.45, 'alpha': 2.3566559387282013e-06, 'max_iter': 900, 'fit_intercept': True}. Best is trial 81 with value: 0.5435778822090033.
#    ✅ Best MAE: 0.5436
#    📊 Final metrics - MAE: 0.5420, RMSE: 0.6771, R²: 0.7948
#    🎯 Best params: {'epsilon': 2.5, 'alpha': 2.3819256646753313e-06, 'max_iter': 450, 'fit_intercept': True}
#
# 🔧 Tuning HuberRegressor for SEC-002
#    Training samples: 727
#   0%|          | 0/100 [00:00<?, ?it/s]
# [I 2025-08-23 08:45:07,993] Trial 0 finished with value: 0.5656744490265578 and parameters: {'epsilon': 1.65, 'alpha': 0.020287488224781474, 'max_iter': 1850, 'fit_intercept': True}. Best is trial 0 with value: 0.5656744490265578.
# [I 2025-08-23 08:45:08,088] Trial 1 finished with value: 0.5657170021783509 and parameters: {'epsilon': 2.05, 'alpha': 0.00027292942889257016, 'max_iter': 250, 'fit_intercept': True}. Best is trial 0 with value: 0.5656744490265578.
# [I 2025-08-23 08:45:08,146] Trial 2 finished with value: 0.5859956075814912 and parameters: {'epsilon': 2.25, 'alpha': 0.017633225786067314, 'max_iter': 250, 'fit_intercept': False}. Best is trial 0 with value: 0.5656744490265578.
# [I 2025-08-23 08:45:08,211] Trial 3 finished with value: 0.5853166155538477 and parameters: {'epsilon': 1.2, 'alpha': 4.243636460919507e-06, 'max_iter': 1750, 'fit_intercept': False}. Best is trial 0 with value: 0.5656744490265578.
# [I 2025-08-23 08:45:08,400] Trial 4 finished with value: 0.5858437204975001 and parameters: {'epsilon': 1.8, 'alpha': 4.369738668046726e-06, 'max_iter': 150, 'fit_intercept': False}. Best is trial 0 with value: 0.5656744490265578.
# [I 2025-08-23 08:45:08,732] Trial 5 finished with value: 0.5853375006629757 and parameters: {'epsilon': 1.3, 'alpha': 0.0077201285140919805, 'max_iter': 2000, 'fit_intercept': False}. Best is trial 0 with value: 0.5656744490265578.
# [I 2025-08-23 08:45:09,090] Trial 6 finished with value: 0.5851835845968726 and parameters: {'epsilon': 1.1, 'alpha': 5.797050981776095e-06, 'max_iter': 1050, 'fit_intercept': False}. Best is trial 0 with value: 0.5656744490265578.
# [I 2025-08-23 08:45:09,195] Trial 7 finished with value: 0.5860007721295866 and parameters: {'epsilon': 2.2, 'alpha': 1.8929552327134183e-06, 'max_iter': 1500, 'fit_intercept': False}. Best is trial 0 with value: 0.5656744490265578.
# [I 2025-08-23 08:45:09,261] Trial 8 finished with value: 0.5860021147959023 and parameters: {'epsilon': 2.45, 'alpha': 3.6377186414264033e-06, 'max_iter': 450, 'fit_intercept': False}. Best is trial 0 with value: 0.5656744490265578.
# [I 2025-08-23 08:45:09,360] Trial 9 finished with value: 0.5852300066081245 and parameters: {'epsilon': 1.15, 'alpha': 0.008000348545264845, 'max_iter': 1050, 'fit_intercept': False}. Best is trial 0 with value: 0.5656744490265578.
# [I 2025-08-23 08:45:09,513] Trial 10 finished with value: 0.5656929825420451 and parameters: {'epsilon': 1.6, 'alpha': 0.08482759217800549, 'max_iter': 1450, 'fit_intercept': True}. Best is trial 0 with value: 0.5656744490265578.
# [I 2025-08-23 08:45:09,703] Trial 11 finished with value: 0.5656665787457933 and parameters: {'epsilon': 1.55, 'alpha': 0.07118656035578044, 'max_iter': 1450, 'fit_intercept': True}. Best is trial 11 with value: 0.5656665787457933.
# [I 2025-08-23 08:45:09,839] Trial 12 finished with value: 0.5656665787476312 and parameters: {'epsilon': 1.55, 'alpha': 0.0006586785236740109, 'max_iter': 1450, 'fit_intercept': True}. Best is trial 11 with value: 0.5656665787457933.
# [I 2025-08-23 08:45:09,994] Trial 13 finished with value: 0.5655961662347757 and parameters: {'epsilon': 1.45, 'alpha': 0.0003445251713464822, 'max_iter': 1150, 'fit_intercept': True}. Best is trial 13 with value: 0.5655961662347757.
# [I 2025-08-23 08:45:10,114] Trial 14 finished with value: 0.5655656699158563 and parameters: {'epsilon': 1.4, 'alpha': 8.515237127964322e-05, 'max_iter': 1000, 'fit_intercept': True}. Best is trial 14 with value: 0.5655656699158563.
# [I 2025-08-23 08:45:10,298] Trial 15 finished with value: 0.5655656699149041 and parameters: {'epsilon': 1.4, 'alpha': 6.210038891452891e-05, 'max_iter': 900, 'fit_intercept': True}. Best is trial 15 with value: 0.5655656699149041.
# [I 2025-08-23 08:45:10,488] Trial 16 finished with value: 0.5657479868550421 and parameters: {'epsilon': 1.85, 'alpha': 4.0569702118678875e-05, 'max_iter': 750, 'fit_intercept': True}. Best is trial 15 with value: 0.5655656699149041.
# [W 2025-08-23 08:45:11,746] Trial 17 failed with parameters: {'epsilon': 1.0, 'alpha': 5.263472745336204e-05, 'max_iter': 750, 'fit_intercept': True} because of the following error: The value nan is not acceptable.
# [W 2025-08-23 08:45:11,749] Trial 17 failed with value np.float64(nan).
# [I 2025-08-23 08:45:11,849] Trial 18 finished with value: 0.5655048941090384 and parameters: {'epsilon': 1.3, 'alpha': 4.170473996247844e-05, 'max_iter': 750, 'fit_intercept': True}. Best is trial 18 with value: 0.5655048941090384.
# [I 2025-08-23 08:45:11,943] Trial 19 finished with value: 0.5659927554901565 and parameters: {'epsilon': 1.05, 'alpha': 2.165545892224278e-05, 'max_iter': 650, 'fit_intercept': True}. Best is trial 18 with value: 0.5655048941090384.
# [I 2025-08-23 08:45:12,050] Trial 20 finished with value: 0.5655481232562839 and parameters: {'epsilon': 1.25, 'alpha': 1.4957134518705217e-05, 'max_iter': 750, 'fit_intercept': True}. Best is trial 18 with value: 0.5655048941090384.
# [I 2025-08-23 08:45:12,290] Trial 21 finished with value: 0.5659033205882521 and parameters: {'epsilon': 1.0, 'alpha': 1.2986852087360784e-05, 'max_iter': 550, 'fit_intercept': True}. Best is trial 18 with value: 0.5655048941090384.
# [I 2025-08-23 08:45:12,393] Trial 22 finished with value: 0.5655048940927043 and parameters: {'epsilon': 1.3, 'alpha': 7.912085846806043e-05, 'max_iter': 850, 'fit_intercept': True}. Best is trial 22 with value: 0.5655048940927043.
# [I 2025-08-23 08:45:12,508] Trial 23 finished with value: 0.5655481231574324 and parameters: {'epsilon': 1.25, 'alpha': 0.00016521860034247803, 'max_iter': 800, 'fit_intercept': True}. Best is trial 22 with value: 0.5655048940927043.
# [I 2025-08-23 08:45:12,627] Trial 24 finished with value: 0.5655048940284307 and parameters: {'epsilon': 1.3, 'alpha': 0.0010992435176480557, 'max_iter': 1200, 'fit_intercept': True}. Best is trial 24 with value: 0.5655048940284307.
# [I 2025-08-23 08:45:12,737] Trial 25 finished with value: 0.5655377520407131 and parameters: {'epsilon': 1.35, 'alpha': 0.0008806575073243163, 'max_iter': 1250, 'fit_intercept': True}. Best is trial 24 with value: 0.5655048940284307.
# [I 2025-08-23 08:45:12,891] Trial 26 finished with value: 0.5657077541407507 and parameters: {'epsilon': 1.75, 'alpha': 0.0016079270489483917, 'max_iter': 1250, 'fit_intercept': True}. Best is trial 24 with value: 0.5655048940284307.
# [I 2025-08-23 08:45:13,035] Trial 27 finished with value: 0.5656345881256073 and parameters: {'epsilon': 1.5, 'alpha': 0.002315004312474435, 'max_iter': 400, 'fit_intercept': True}. Best is trial 24 with value: 0.5655048940284307.
# [I 2025-08-23 08:45:13,133] Trial 28 finished with value: 0.5657584482549208 and parameters: {'epsilon': 1.9, 'alpha': 0.00011346863238866745, 'max_iter': 900, 'fit_intercept': True}. Best is trial 24 with value: 0.5655048940284307.
# [I 2025-08-23 08:45:13,257] Trial 29 finished with value: 0.5658362331164603 and parameters: {'epsilon': 1.15, 'alpha': 3.83546759753475e-05, 'max_iter': 600, 'fit_intercept': True}. Best is trial 24 with value: 0.5655048940284307.
# [I 2025-08-23 08:45:13,363] Trial 30 finished with value: 0.5656744489767753 and parameters: {'epsilon': 1.65, 'alpha': 0.00032199435266006324, 'max_iter': 1250, 'fit_intercept': True}. Best is trial 24 with value: 0.5655048940284307.
# [I 2025-08-23 08:45:13,480] Trial 31 finished with value: 0.5656744498328206 and parameters: {'epsilon': 1.65, 'alpha': 0.0035311298175961536, 'max_iter': 1600, 'fit_intercept': True}. Best is trial 24 with value: 0.5655048940284307.
# [I 2025-08-23 08:45:13,678] Trial 32 finished with value: 0.5655481226294456 and parameters: {'epsilon': 1.25, 'alpha': 0.0010438720848211438, 'max_iter': 1150, 'fit_intercept': True}. Best is trial 24 with value: 0.5655048940284307.
# [I 2025-08-23 08:45:13,796] Trial 33 finished with value: 0.5655377518724191 and parameters: {'epsilon': 1.35, 'alpha': 0.0006549545234035094, 'max_iter': 1250, 'fit_intercept': True}. Best is trial 24 with value: 0.5655048940284307.
# [I 2025-08-23 08:45:13,917] Trial 34 finished with value: 0.5655377520491566 and parameters: {'epsilon': 1.35, 'alpha': 0.00019555846118472092, 'max_iter': 900, 'fit_intercept': True}. Best is trial 24 with value: 0.5655048940284307.
# [I 2025-08-23 08:45:14,050] Trial 35 finished with value: 0.5657821619499848 and parameters: {'epsilon': 1.0, 'alpha': 0.0005127348948834229, 'max_iter': 1350, 'fit_intercept': True}. Best is trial 24 with value: 0.5655048940284307.
# [I 2025-08-23 08:45:14,194] Trial 36 finished with value: 0.5657325870738977 and parameters: {'epsilon': 2.0, 'alpha': 0.006327904368786406, 'max_iter': 1750, 'fit_intercept': True}. Best is trial 24 with value: 0.5655048940284307.
# [I 2025-08-23 08:45:14,339] Trial 37 finished with value: 0.5655961662411286 and parameters: {'epsilon': 1.45, 'alpha': 0.00013482085261063174, 'max_iter': 1150, 'fit_intercept': True}. Best is trial 24 with value: 0.5655048940284307.
# [I 2025-08-23 08:45:14,444] Trial 38 finished with value: 0.5658362331207774 and parameters: {'epsilon': 1.15, 'alpha': 0.019429155025265765, 'max_iter': 400, 'fit_intercept': True}. Best is trial 24 with value: 0.5655048940284307.
# [I 2025-08-23 08:45:14,540] Trial 39 finished with value: 0.5853375006634074 and parameters: {'epsilon': 1.3, 'alpha': 4.9214105539347566e-05, 'max_iter': 950, 'fit_intercept': False}. Best is trial 24 with value: 0.5655048940284307.
# [I 2025-08-23 08:45:14,677] Trial 40 finished with value: 0.5656849718831088 and parameters: {'epsilon': 1.2, 'alpha': 2.3696476509680538e-05, 'max_iter': 1650, 'fit_intercept': True}. Best is trial 24 with value: 0.5655048940284307.
# [I 2025-08-23 08:45:14,756] Trial 41 finished with value: 0.5851835845968791 and parameters: {'epsilon': 1.1, 'alpha': 8.180775695750652e-06, 'max_iter': 200, 'fit_intercept': False}. Best is trial 24 with value: 0.5655048940284307.
# [I 2025-08-23 08:45:14,872] Trial 42 finished with value: 0.5655377520727456 and parameters: {'epsilon': 1.35, 'alpha': 0.0007317683104332936, 'max_iter': 1250, 'fit_intercept': True}. Best is trial 24 with value: 0.5655048940284307.
# [I 2025-08-23 08:45:15,100] Trial 43 finished with value: 0.5655377520747127 and parameters: {'epsilon': 1.35, 'alpha': 0.0013097900975268617, 'max_iter': 1350, 'fit_intercept': True}. Best is trial 24 with value: 0.5655048940284307.
# [I 2025-08-23 08:45:15,209] Trial 44 finished with value: 0.5655961662508048 and parameters: {'epsilon': 1.45, 'alpha': 0.00449603956107087, 'max_iter': 1100, 'fit_intercept': True}. Best is trial 24 with value: 0.5655048940284307.
# [I 2025-08-23 08:45:15,366] Trial 45 finished with value: 0.5656665787188497 and parameters: {'epsilon': 1.55, 'alpha': 0.0002602436672561799, 'max_iter': 1300, 'fit_intercept': True}. Best is trial 24 with value: 0.5655048940284307.
# [I 2025-08-23 08:45:15,470] Trial 46 finished with value: 0.5853375006634108 and parameters: {'epsilon': 1.3, 'alpha': 0.00044387110645886915, 'max_iter': 800, 'fit_intercept': False}. Best is trial 24 with value: 0.5655048940284307.
# [I 2025-08-23 08:45:15,681] Trial 47 finished with value: 0.5656849676307701 and parameters: {'epsilon': 1.2, 'alpha': 0.002148228914039223, 'max_iter': 1050, 'fit_intercept': True}. Best is trial 24 with value: 0.5655048940284307.
# [I 2025-08-23 08:45:15,874] Trial 48 finished with value: 0.5656969231237836 and parameters: {'epsilon': 1.7000000000000002, 'alpha': 0.0009222749794088473, 'max_iter': 2000, 'fit_intercept': True}. Best is trial 24 with value: 0.5655048940284307.
# [I 2025-08-23 08:45:16,177] Trial 49 finished with value: 0.5656862582106894 and parameters: {'epsilon': 2.4000000000000004, 'alpha': 1.4179624516597898e-06, 'max_iter': 1500, 'fit_intercept': True}. Best is trial 24 with value: 0.5655048940284307.
# [I 2025-08-23 08:45:16,304] Trial 50 finished with value: 0.5853369573099144 and parameters: {'epsilon': 1.4, 'alpha': 0.044224912577006635, 'max_iter': 700, 'fit_intercept': False}. Best is trial 24 with value: 0.5655048940284307.
# [I 2025-08-23 08:45:16,426] Trial 51 finished with value: 0.5656345883771332 and parameters: {'epsilon': 1.5, 'alpha': 0.009720660299927788, 'max_iter': 1000, 'fit_intercept': True}. Best is trial 24 with value: 0.5655048940284307.
# [I 2025-08-23 08:45:16,537] Trial 52 finished with value: 0.5655377519503114 and parameters: {'epsilon': 1.35, 'alpha': 7.369057577539308e-05, 'max_iter': 900, 'fit_intercept': True}. Best is trial 24 with value: 0.5655048940284307.
# [I 2025-08-23 08:45:16,799] Trial 53 finished with value: 0.5659643844096265 and parameters: {'epsilon': 1.1, 'alpha': 8.41225225208378e-05, 'max_iter': 850, 'fit_intercept': True}. Best is trial 24 with value: 0.5655048940284307.
# [I 2025-08-23 08:45:16,927] Trial 54 finished with value: 0.5655048941117116 and parameters: {'epsilon': 1.3, 'alpha': 0.0002470027782268577, 'max_iter': 550, 'fit_intercept': True}. Best is trial 24 with value: 0.5655048940284307.
# [I 2025-08-23 08:45:17,047] Trial 55 finished with value: 0.5656849710617026 and parameters: {'epsilon': 1.2, 'alpha': 2.887579330918977e-05, 'max_iter': 500, 'fit_intercept': True}. Best is trial 24 with value: 0.5655048940284307.
# [I 2025-08-23 08:45:17,148] Trial 56 finished with value: 0.5655048940844647 and parameters: {'epsilon': 1.3, 'alpha': 6.822966762214305e-05, 'max_iter': 600, 'fit_intercept': True}. Best is trial 24 with value: 0.5655048940284307.
# [I 2025-08-23 08:45:17,265] Trial 57 finished with value: 0.565548123130164 and parameters: {'epsilon': 1.25, 'alpha': 0.00019498927183949792, 'max_iter': 650, 'fit_intercept': True}. Best is trial 24 with value: 0.5655048940284307.
# [I 2025-08-23 08:45:17,400] Trial 58 finished with value: 0.5655048940975893 and parameters: {'epsilon': 1.3, 'alpha': 0.00010196648772007383, 'max_iter': 300, 'fit_intercept': True}. Best is trial 24 with value: 0.5655048940284307.
# [I 2025-08-23 08:45:17,520] Trial 59 finished with value: 0.565992755493044 and parameters: {'epsilon': 1.05, 'alpha': 0.00011339213207453951, 'max_iter': 350, 'fit_intercept': True}. Best is trial 24 with value: 0.5655048940284307.
# [I 2025-08-23 08:45:17,628] Trial 60 finished with value: 0.5656345880371236 and parameters: {'epsilon': 1.5, 'alpha': 1.2703332384865058e-05, 'max_iter': 300, 'fit_intercept': True}. Best is trial 24 with value: 0.5655048940284307.
# [I 2025-08-23 08:45:17,719] Trial 61 finished with value: 0.5859978689026295 and parameters: {'epsilon': 2.1500000000000004, 'alpha': 5.662529439532805e-05, 'max_iter': 100, 'fit_intercept': False}. Best is trial 24 with value: 0.5655048940284307.
# [I 2025-08-23 08:45:17,819] Trial 62 finished with value: 0.5655048940999218 and parameters: {'epsilon': 1.3, 'alpha': 0.00026805141765486826, 'max_iter': 500, 'fit_intercept': True}. Best is trial 24 with value: 0.5655048940284307.
# [I 2025-08-23 08:45:17,931] Trial 63 finished with value: 0.5655048941074408 and parameters: {'epsilon': 1.3, 'alpha': 0.0002691499294309878, 'max_iter': 550, 'fit_intercept': True}. Best is trial 24 with value: 0.5655048940284307.
# [I 2025-08-23 08:45:18,056] Trial 64 finished with value: 0.5656849738732281 and parameters: {'epsilon': 1.2, 'alpha': 3.314775248891636e-05, 'max_iter': 500, 'fit_intercept': True}. Best is trial 24 with value: 0.5655048940284307.
# [I 2025-08-23 08:45:18,292] Trial 65 finished with value: 0.5655656699183506 and parameters: {'epsilon': 1.4, 'alpha': 0.00012046198122701473, 'max_iter': 250, 'fit_intercept': True}. Best is trial 24 with value: 0.5655048940284307.
# [I 2025-08-23 08:45:18,394] Trial 66 finished with value: 0.5655481232238735 and parameters: {'epsilon': 1.25, 'alpha': 7.08127492429927e-05, 'max_iter': 650, 'fit_intercept': True}. Best is trial 24 with value: 0.5655048940284307.
# [I 2025-08-23 08:45:18,496] Trial 67 finished with value: 0.5658362331111443 and parameters: {'epsilon': 1.15, 'alpha': 0.00041683304742366826, 'max_iter': 450, 'fit_intercept': True}. Best is trial 24 with value: 0.5655048940284307.
# [I 2025-08-23 08:45:18,618] Trial 68 finished with value: 0.5655961662456839 and parameters: {'epsilon': 1.45, 'alpha': 1.966783206800716e-05, 'max_iter': 750, 'fit_intercept': True}. Best is trial 24 with value: 0.5655048940284307.
# [I 2025-08-23 08:45:18,714] Trial 69 finished with value: 0.5655048940801154 and parameters: {'epsilon': 1.3, 'alpha': 0.00014936653569614302, 'max_iter': 550, 'fit_intercept': True}. Best is trial 24 with value: 0.5655048940284307.
# [I 2025-08-23 08:45:18,810] Trial 70 finished with value: 0.5656665787015089 and parameters: {'epsilon': 1.55, 'alpha': 0.00013926200569048974, 'max_iter': 550, 'fit_intercept': True}. Best is trial 24 with value: 0.5655048940284307.
# [I 2025-08-23 08:45:18,935] Trial 71 finished with value: 0.5659927554953809 and parameters: {'epsilon': 1.05, 'alpha': 0.0002562484105708404, 'max_iter': 350, 'fit_intercept': True}. Best is trial 24 with value: 0.5655048940284307.
# [I 2025-08-23 08:45:19,044] Trial 72 finished with value: 0.5655048941174978 and parameters: {'epsilon': 1.3, 'alpha': 4.8361268302809806e-05, 'max_iter': 600, 'fit_intercept': True}. Best is trial 24 with value: 0.5655048940284307.
# [I 2025-08-23 08:45:19,149] Trial 73 finished with value: 0.5655656699153494 and parameters: {'epsilon': 1.4, 'alpha': 9.627030678325208e-05, 'max_iter': 700, 'fit_intercept': True}. Best is trial 24 with value: 0.5655048940284307.
# [I 2025-08-23 08:45:19,244] Trial 74 finished with value: 0.56554812315888 and parameters: {'epsilon': 1.25, 'alpha': 0.00017036281252359443, 'max_iter': 450, 'fit_intercept': True}. Best is trial 24 with value: 0.5655048940284307.
# [I 2025-08-23 08:45:19,468] Trial 75 finished with value: 0.5655048940704229 and parameters: {'epsilon': 1.3, 'alpha': 0.0004966532401717655, 'max_iter': 600, 'fit_intercept': True}. Best is trial 24 with value: 0.5655048940284307.
# [I 2025-08-23 08:45:19,596] Trial 76 finished with value: 0.5659643844558445 and parameters: {'epsilon': 1.1, 'alpha': 0.0005795141395706422, 'max_iter': 400, 'fit_intercept': True}. Best is trial 24 with value: 0.5655048940284307.
# [I 2025-08-23 08:45:19,688] Trial 77 finished with value: 0.5655048940763941 and parameters: {'epsilon': 1.3, 'alpha': 0.00030579171425471546, 'max_iter': 600, 'fit_intercept': True}. Best is trial 24 with value: 0.5655048940284307.
# [I 2025-08-23 08:45:19,798] Trial 78 finished with value: 0.5658362331178391 and parameters: {'epsilon': 1.15, 'alpha': 0.00038907015079831935, 'max_iter': 300, 'fit_intercept': True}. Best is trial 24 with value: 0.5655048940284307.
# [I 2025-08-23 08:45:19,899] Trial 79 finished with value: 0.5655961662762186 and parameters: {'epsilon': 1.45, 'alpha': 0.0013016674136873344, 'max_iter': 600, 'fit_intercept': True}. Best is trial 24 with value: 0.5655048940284307.
# [I 2025-08-23 08:45:19,989] Trial 80 finished with value: 0.5853166155537691 and parameters: {'epsilon': 1.2, 'alpha': 0.00032515745624907066, 'max_iter': 500, 'fit_intercept': False}. Best is trial 24 with value: 0.5655048940284307.
# [I 2025-08-23 08:45:20,099] Trial 81 finished with value: 0.5655377520365455 and parameters: {'epsilon': 1.35, 'alpha': 0.00019004929597264694, 'max_iter': 800, 'fit_intercept': True}. Best is trial 24 with value: 0.5655048940284307.
# [I 2025-08-23 08:45:20,211] Trial 82 finished with value: 0.5655481228993597 and parameters: {'epsilon': 1.25, 'alpha': 0.0005297256757741328, 'max_iter': 700, 'fit_intercept': True}. Best is trial 24 with value: 0.5655048940284307.
# [I 2025-08-23 08:45:20,298] Trial 83 finished with value: 0.5655656699235321 and parameters: {'epsilon': 1.4, 'alpha': 0.00024199583151428156, 'max_iter': 450, 'fit_intercept': True}. Best is trial 24 with value: 0.5655048940284307.
# [I 2025-08-23 08:45:20,393] Trial 84 finished with value: 0.5655048940230666 and parameters: {'epsilon': 1.3, 'alpha': 0.0021646908286847015, 'max_iter': 600, 'fit_intercept': True}. Best is trial 84 with value: 0.5655048940230666.
# [I 2025-08-23 08:45:20,603] Trial 85 finished with value: 0.5655048940477638 and parameters: {'epsilon': 1.3, 'alpha': 0.002696004498937538, 'max_iter': 200, 'fit_intercept': True}. Best is trial 84 with value: 0.5655048940230666.
# [I 2025-08-23 08:45:20,715] Trial 86 finished with value: 0.565537751938703 and parameters: {'epsilon': 1.35, 'alpha': 0.0036617342419960003, 'max_iter': 200, 'fit_intercept': True}. Best is trial 84 with value: 0.5655048940230666.
# [I 2025-08-23 08:45:20,860] Trial 87 finished with value: 0.5656849720318472 and parameters: {'epsilon': 1.2, 'alpha': 0.002130795022654738, 'max_iter': 100, 'fit_intercept': True}. Best is trial 84 with value: 0.5655048940230666.
# [I 2025-08-23 08:45:20,960] Trial 88 finished with value: 0.5655656699136744 and parameters: {'epsilon': 1.4, 'alpha': 0.0017415242475228134, 'max_iter': 150, 'fit_intercept': True}. Best is trial 84 with value: 0.5655048940230666.
# [I 2025-08-23 08:45:21,057] Trial 89 finished with value: 0.5658362331142284 and parameters: {'epsilon': 1.15, 'alpha': 0.002830970524624535, 'max_iter': 250, 'fit_intercept': True}. Best is trial 84 with value: 0.5655048940230666.
# [I 2025-08-23 08:45:21,160] Trial 90 finished with value: 0.5655048938090605 and parameters: {'epsilon': 1.3, 'alpha': 0.010546198053523689, 'max_iter': 650, 'fit_intercept': True}. Best is trial 90 with value: 0.5655048938090605.
# [I 2025-08-23 08:45:21,248] Trial 91 finished with value: 0.5655481082623699 and parameters: {'epsilon': 1.25, 'alpha': 0.011684957405061551, 'max_iter': 850, 'fit_intercept': True}. Best is trial 90 with value: 0.5655048938090605.
# [I 2025-08-23 08:45:21,336] Trial 92 finished with value: 0.5655048937249889 and parameters: {'epsilon': 1.3, 'alpha': 0.013108395699189833, 'max_iter': 600, 'fit_intercept': True}. Best is trial 92 with value: 0.5655048937249889.
# [I 2025-08-23 08:45:21,431] Trial 93 finished with value: 0.5655377519999899 and parameters: {'epsilon': 1.35, 'alpha': 0.013323755782340907, 'max_iter': 650, 'fit_intercept': True}. Best is trial 92 with value: 0.5655048937249889.
# [I 2025-08-23 08:45:21,630] Trial 94 finished with value: 0.5655048928382531 and parameters: {'epsilon': 1.3, 'alpha': 0.043570676782234655, 'max_iter': 600, 'fit_intercept': True}. Best is trial 94 with value: 0.5655048928382531.
# [I 2025-08-23 08:45:21,988] Trial 95 finished with value: 0.5655048933556586 and parameters: {'epsilon': 1.3, 'alpha': 0.026194010026021546, 'max_iter': 700, 'fit_intercept': True}. Best is trial 94 with value: 0.5655048928382531.
# [I 2025-08-23 08:45:22,137] Trial 96 finished with value: 0.5655656699416423 and parameters: {'epsilon': 1.4, 'alpha': 0.030079296712642922, 'max_iter': 750, 'fit_intercept': True}. Best is trial 94 with value: 0.5655048928382531.
# [I 2025-08-23 08:45:22,229] Trial 97 finished with value: 0.5656929825851348 and parameters: {'epsilon': 1.6, 'alpha': 0.06732735710448669, 'max_iter': 700, 'fit_intercept': True}. Best is trial 94 with value: 0.5655048928382531.
# [I 2025-08-23 08:45:22,314] Trial 98 finished with value: 0.5853457914760499 and parameters: {'epsilon': 1.25, 'alpha': 0.024434941901113796, 'max_iter': 550, 'fit_intercept': False}. Best is trial 94 with value: 0.5655048928382531.
# [I 2025-08-23 08:45:22,430] Trial 99 finished with value: 0.5655961662675788 and parameters: {'epsilon': 1.45, 'alpha': 0.005545130079722583, 'max_iter': 650, 'fit_intercept': True}. Best is trial 94 with value: 0.5655048928382531.
# [I 2025-08-23 08:45:22,501] A new study created in memory with name: huber_tuning_SEC-003
#    ✅ Best MAE: 0.5655
#    📊 Final metrics - MAE: 0.5644, RMSE: 0.7095, R²: 0.8244
#    🎯 Best params: {'epsilon': 1.3, 'alpha': 0.043570676782234655, 'max_iter': 600, 'fit_intercept': True}
#
# 🔧 Tuning HuberRegressor for SEC-003
# ...
# [I 2025-08-23 08:45:58,419] Trial 51 finished with value: 0.523741003620257 and parameters: {'epsilon': 2.2, 'alpha': 2.70451633581817e-05, 'max_iter': 1450, 'fit_intercept': True}. Best is trial 33 with value: 0.5237410034084019.
# [I 2025-08-23 08:45:58,469] Trial 52 finished with value: 0.527223965987519 and parameters: {'epsilon': 2.25, 'alpha': 3.441986626117896e-05, 'max_iter': 1650, 'fit_intercept': True}. Best is trial 33 with value: 0.5237410034084019.
# [I 2025-08-23 08:45:58,515] Trial 53 finished with value: 0.5237410034364192 and parameters: {'epsilon': 2.2, 'alpha': 7.480242497494419e-05, 'max_iter': 1450, 'fit_intercept': True}. Best is trial 33 with value: 0.5237410034084019.
# [I 2025-08-23 08:45:58,560] Trial 54 finished with value: 0.5237417679756059 and parameters: {'epsilon': 2.35, 'alpha': 2.469167581679071e-05, 'max_iter': 1500, 'fit_intercept': True}. Best is trial 33 with value: 0.5237410034084019.
# [I 2025-08-23 08:45:58,603] Trial 55 finished with value: 0.5237562591773106 and parameters: {'epsilon': 2.1, 'alpha': 5.3354443588257914e-05, 'max_iter': 1350, 'fit_intercept': True}. Best is trial 33 with value: 0.5237410034084019.
# [I 2025-08-23 08:45:58,649] Trial 56 finished with value: 0.5237415251143918 and parameters: {'epsilon': 2.45, 'alpha': 0.09380510865030202, 'max_iter': 1450, 'fit_intercept': True}. Best is trial 33 with value: 0.5237410034084019.
# [I 2025-08-23 08:45:58,705] Trial 57 finished with value: 0.5237445758719355 and parameters: {'epsilon': 2.1500000000000004, 'alpha': 0.00024281385197116298, 'max_iter': 1600, 'fit_intercept': True}. Best is trial 33 with value: 0.5237410034084019.
# [I 2025-08-23 08:45:58,751] Trial 58 finished with value: 0.5303256012530515 and parameters: {'epsilon': 2.3, 'alpha': 8.62000429895469e-05, 'max_iter': 1750, 'fit_intercept': True}. Best is trial 33 with value: 0.5237410034084019.
# [I 2025-08-23 08:45:58,809] Trial 59 finished with value: 0.5237639009351 and parameters: {'epsilon': 2.05, 'alpha': 1.2058761679962944e-05, 'max_iter': 1300, 'fit_intercept': True}. Best is trial 33 with value: 0.5237410034084019.
# [I 2025-08-23 08:45:58,968] Trial 60 finished with value: 0.5272239659304498 and parameters: {'epsilon': 2.25, 'alpha': 0.025929253469926705, 'max_iter': 1550, 'fit_intercept': True}. Best is trial 33 with value: 0.5237410034084019.
# [I 2025-08-23 08:45:59,081] Trial 61 finished with value: 0.5237445771683427 and parameters: {'epsilon': 2.1500000000000004, 'alpha': 0.00015619149475355716, 'max_iter': 1150, 'fit_intercept': True}. Best is trial 33 with value: 0.5237410034084019.
# [I 2025-08-23 08:45:59,146] Trial 62 finished with value: 0.5237410033750883 and parameters: {'epsilon': 2.2, 'alpha': 4.514009372796933e-05, 'max_iter': 1250, 'fit_intercept': True}. Best is trial 62 with value: 0.5237410033750883.
# [I 2025-08-23 08:45:59,209] Trial 63 finished with value: 0.5237415331560786 and parameters: {'epsilon': 2.45, 'alpha': 5.478319573257044e-05, 'max_iter': 1300, 'fit_intercept': True}. Best is trial 62 with value: 0.5237410033750883.
# [I 2025-08-23 08:45:59,268] Trial 64 finished with value: 0.5237410036506106 and parameters: {'epsilon': 2.2, 'alpha': 2.125941696768477e-05, 'max_iter': 1400, 'fit_intercept': True}. Best is trial 62 with value: 0.5237410033750883.
# [I 2025-08-23 08:45:59,307] Trial 65 finished with value: 0.5237562590172038 and parameters: {'epsilon': 2.1, 'alpha': 3.4558604867048176e-05, 'max_iter': 1250, 'fit_intercept': True}. Best is trial 62 with value: 0.5237410033750883.
# [I 2025-08-23 08:45:59,358] Trial 66 finished with value: 0.5237417679692984 and parameters: {'epsilon': 2.35, 'alpha': 5.8541393411739194e-06, 'max_iter': 1450, 'fit_intercept': True}. Best is trial 62 with value: 0.5237410033750883.
# [I 2025-08-23 08:45:59,407] Trial 67 finished with value: 0.523780374658686 and parameters: {'epsilon': 1.9500000000000002, 'alpha': 1.3214064820019697e-05, 'max_iter': 1000, 'fit_intercept': True}. Best is trial 62 with value: 0.5237410033750883.
# [I 2025-08-23 08:45:59,443] Trial 68 finished with value: 0.5456836230378596 and parameters: {'epsilon': 2.25, 'alpha': 4.237725366250421e-05, 'max_iter': 1600, 'fit_intercept': False}. Best is trial 62 with value: 0.5237410033750883.
# [I 2025-08-23 08:45:59,495] Trial 69 finished with value: 0.523741404981236 and parameters: {'epsilon': 2.4000000000000004, 'alpha': 0.0002849196280114918, 'max_iter': 1500, 'fit_intercept': True}. Best is trial 62 with value: 0.5237410033750883.
# [I 2025-08-23 08:45:59,554] Trial 70 finished with value: 0.52374100358941 and parameters: {'epsilon': 2.2, 'alpha': 8.564900509396043e-05, 'max_iter': 1100, 'fit_intercept': True}. Best is trial 62 with value: 0.5237410033750883.
# [I 2025-08-23 08:45:59,602] Trial 71 finished with value: 0.5237410035811316 and parameters: {'epsilon': 2.2, 'alpha': 9.135579151722859e-05, 'max_iter': 1250, 'fit_intercept': True}. Best is trial 62 with value: 0.5237410033750883.
# [I 2025-08-23 08:45:59,653] Trial 72 finished with value: 0.5237445751651659 and parameters: {'epsilon': 2.1500000000000004, 'alpha': 9.513589342882729e-05, 'max_iter': 1100, 'fit_intercept': True}. Best is trial 62 with value: 0.5237410033750883.
# [I 2025-08-23 08:45:59,703] Trial 73 finished with value: 0.5303256012376456 and parameters: {'epsilon': 2.3, 'alpha': 6.120301557108788e-05, 'max_iter': 1200, 'fit_intercept': True}. Best is trial 62 with value: 0.5237410033750883.
# [I 2025-08-23 08:45:59,757] Trial 74 finished with value: 0.5237638985917714 and parameters: {'epsilon': 2.05, 'alpha': 0.00011946008587769646, 'max_iter': 1000, 'fit_intercept': True}. Best is trial 62 with value: 0.5237410033750883.
# [I 2025-08-23 08:45:59,802] Trial 75 finished with value: 0.5272239659921409 and parameters: {'epsilon': 2.25, 'alpha': 7.621812703333564e-05, 'max_iter': 1100, 'fit_intercept': True}. Best is trial 62 with value: 0.5237410033750883.
# [I 2025-08-23 08:45:59,841] Trial 76 finished with value: 0.5237417679838666 and parameters: {'epsilon': 2.35, 'alpha': 0.0005736645389892724, 'max_iter': 1250, 'fit_intercept': True}. Best is trial 62 with value: 0.5237410033750883.
# [I 2025-08-23 08:45:59,890] Trial 77 finished with value: 0.5237410034453959 and parameters: {'epsilon': 2.2, 'alpha': 0.0003970221320906343, 'max_iter': 1350, 'fit_intercept': True}. Best is trial 62 with value: 0.5237410033750883.
# [I 2025-08-23 08:45:59,956] Trial 78 finished with value: 0.5237562590946683 and parameters: {'epsilon': 2.1, 'alpha': 0.0009454344052122015, 'max_iter': 1300, 'fit_intercept': True}. Best is trial 62 with value: 0.5237410033750883.
# [I 2025-08-23 08:46:00,008] Trial 79 finished with value: 0.5457243251848563 and parameters: {'epsilon': 1.9500000000000002, 'alpha': 0.00031864610385436316, 'max_iter': 1400, 'fit_intercept': False}. Best is trial 62 with value: 0.5237410033750883.
# [I 2025-08-23 08:46:00,086] Trial 80 finished with value: 0.5264621496108237 and parameters: {'epsilon': 1.5, 'alpha': 0.00168427884617525, 'max_iter': 1350, 'fit_intercept': True}. Best is trial 62 with value: 0.5237410033750883.
# [I 2025-08-23 08:46:00,224] Trial 81 finished with value: 0.5237410033997983 and parameters: {'epsilon': 2.2, 'alpha': 0.00016802284942871369, 'max_iter': 1150, 'fit_intercept': True}. Best is trial 62 with value: 0.5237410033750883.
# [I 2025-08-23 08:46:00,329] Trial 82 finished with value: 0.5237445751017571 and parameters: {'epsilon': 2.1500000000000004, 'alpha': 0.0004163410246237432, 'max_iter': 1200, 'fit_intercept': True}. Best is trial 62 with value: 0.5237410033750883.
# [I 2025-08-23 08:46:00,414] Trial 83 finished with value: 0.5303256012296973 and parameters: {'epsilon': 2.3, 'alpha': 0.00020888514421275447, 'max_iter': 1550, 'fit_intercept': True}. Best is trial 62 with value: 0.5237410033750883.
# [I 2025-08-23 08:46:00,496] Trial 84 finished with value: 0.5272239660230371 and parameters: {'epsilon': 2.25, 'alpha': 0.00016875695844224635, 'max_iter': 1150, 'fit_intercept': True}. Best is trial 62 with value: 0.5237410033750883.
# [I 2025-08-23 08:46:00,596] Trial 85 finished with value: 0.5237410035009616 and parameters: {'epsilon': 2.2, 'alpha': 0.00013606869969291294, 'max_iter': 1250, 'fit_intercept': True}. Best is trial 62 with value: 0.5237410033750883.
# [I 2025-08-23 08:46:00,751] Trial 86 finished with value: 0.5237638977813998 and parameters: {'epsilon': 2.05, 'alpha': 0.003638912516761477, 'max_iter': 1650, 'fit_intercept': True}. Best is trial 62 with value: 0.5237410033750883.
# [I 2025-08-23 08:46:00,843] Trial 87 finished with value: 0.529614588522674 and parameters: {'epsilon': 1.15, 'alpha': 0.06342098924788021, 'max_iter': 1050, 'fit_intercept': True}. Best is trial 62 with value: 0.5237410033750883.
# [I 2025-08-23 08:46:00,924] Trial 88 finished with value: 0.5237562588677843 and parameters: {'epsilon': 2.1, 'alpha': 0.00012958173142355132, 'max_iter': 1350, 'fit_intercept': True}. Best is trial 62 with value: 0.5237410033750883.
# [I 2025-08-23 08:46:01,013] Trial 89 finished with value: 0.5303256013227957 and parameters: {'epsilon': 2.3, 'alpha': 0.000592967292883179, 'max_iter': 1400, 'fit_intercept': True}. Best is trial 62 with value: 0.5237410033750883.
# [I 2025-08-23 08:46:01,079] Trial 90 finished with value: 0.5456832172626475 and parameters: {'epsilon': 2.1500000000000004, 'alpha': 0.0012614618824829656, 'max_iter': 950, 'fit_intercept': False}. Best is trial 62 with value: 0.5237410033750883.
# [I 2025-08-23 08:46:01,282] Trial 91 finished with value: 0.5237410035725185 and parameters: {'epsilon': 2.2, 'alpha': 4.53640028979592e-05, 'max_iter': 1250, 'fit_intercept': True}. Best is trial 62 with value: 0.5237410033750883.
# [I 2025-08-23 08:46:01,379] Trial 92 finished with value: 0.52376746762937 and parameters: {'epsilon': 2.0, 'alpha': 3.98800979528628e-05, 'max_iter': 1300, 'fit_intercept': True}. Best is trial 62 with value: 0.5237410033750883.
# [I 2025-08-23 08:46:01,474] Trial 93 finished with value: 0.5272239659587914 and parameters: {'epsilon': 2.25, 'alpha': 0.014328422888807741, 'max_iter': 1200, 'fit_intercept': True}. Best is trial 62 with value: 0.5237410033750883.
# [I 2025-08-23 08:46:01,671] Trial 94 finished with value: 0.5237410034573077 and parameters: {'epsilon': 2.2, 'alpha': 6.512785139823318e-05, 'max_iter': 1450, 'fit_intercept': True}. Best is trial 62 with value: 0.5237410033750883.
# [I 2025-08-23 08:46:01,796] Trial 95 finished with value: 0.5237562590302818 and parameters: {'epsilon': 2.1, 'alpha': 3.1061638027798702e-06, 'max_iter': 1500, 'fit_intercept': True}. Best is trial 62 with value: 0.5237410033750883.
# [I 2025-08-23 08:46:01,879] Trial 96 finished with value: 0.5237417679754464 and parameters: {'epsilon': 2.35, 'alpha': 6.751009031483383e-05, 'max_iter': 1400, 'fit_intercept': True}. Best is trial 62 with value: 0.5237410033750883.
# [I 2025-08-23 08:46:01,945] Trial 97 finished with value: 0.5237445765165785 and parameters: {'epsilon': 2.1500000000000004, 'alpha': 2.1701573197270804e-05, 'max_iter': 1600, 'fit_intercept': True}. Best is trial 62 with value: 0.5237410033750883.
# [I 2025-08-23 08:46:02,033] Trial 98 finished with value: 0.5272239658033934 and parameters: {'epsilon': 2.25, 'alpha': 0.0002617318514797105, 'max_iter': 1750, 'fit_intercept': True}. Best is trial 62 with value: 0.5237410033750883.
# [I 2025-08-23 08:46:02,095] Trial 99 finished with value: 0.5237410037114113 and parameters: {'epsilon': 2.2, 'alpha': 0.00039280096636608444, 'max_iter': 1700, 'fit_intercept': True}. Best is trial 62 with value: 0.5237410033750883.
#    ✅ Best MAE: 0.5237
#    📊 Final metrics - MAE: 0.5222, RMSE: 0.6594, R²: 0.9380
#    🎯 Best params: {'epsilon': 2.2, 'alpha': 4.514009372796933e-05, 'max_iter': 1250, 'fit_intercept': True}
#
# ✅ Tuning completed for 6 sections
#
# 📊 TUNING RESULTS ANALYSIS
# ============================================================
# 🎯 DETAILED RESULTS:
#    Section  Best_Epsilon  Best_Alpha  Best_MaxIter  Fit_Intercept  CV_MAE  \
# 0  SEC-001           2.5      0.0000           450           True  0.5436
# 1  SEC-002           1.3      0.0436           600           True  0.5655
# 2  SEC-003           1.3      0.0000          1550           True  0.5526
# 3  SEC-004           1.0      0.0021           300           True  0.5389
# 4  SEC-005           1.4      0.0002          1350           True  0.5222
# 5  SEC-006           2.2      0.0000          1250           True  0.5237
#
#    Final_MAE  Final_RMSE  Final_R2  Training_Samples
# 0     0.5420      0.6771    0.7948               727
# 1     0.5644      0.7095    0.8244               727
# 2     0.5469      0.6941    0.7624               727
# 3     0.5375      0.6858    0.8131               727
# 4     0.5205      0.6688    0.9668               727
# 5     0.5222      0.6594    0.9380               727
#
# 📈 COMPARISON WITH DEFAULT PARAMETERS
# ========================================
# 🆚 TUNED vs DEFAULT COMPARISON:
#    Section  Final_MAE  Final_R2  Default_MAE  Default_R2  MAE_Improvement  \
# 0  SEC-001     0.5420    0.7948       0.5417      0.7948          -0.0004
# 1  SEC-002     0.5644    0.8244       0.5644      0.8244           0.0001
# 2  SEC-003     0.5469    0.7624       0.5470      0.7625           0.0002
# 3  SEC-004     0.5375    0.8131       0.5380      0.8139           0.0006
# 4  SEC-005     0.5205    0.9668       0.5205      0.9668           0.0000
# 5  SEC-006     0.5222    0.9380       0.5312      0.9352           0.0090
#
#    R2_Improvement
# 0          0.0001
# 1         -0.0000
# 2         -0.0001
# 3         -0.0008
# 4         -0.0000
# 5          0.0029
#
# 📊 SUMMARY:
#    Average MAE improvement: 0.0016
#    Average R² improvement: 0.0004
#    Sections with improved MAE: 5/6
#    Sections with improved R²: 2/6
#
# 💾 SAVING OPTIMIZED PARAMETERS
# ========================================
# 🔧 OPTIMIZED HUBER PARAMETERS:
# # Copy this to your main code:
# OPTIMIZED_HUBER_PARAMS = {
#     'SEC-001': {'epsilon': 2.5, 'alpha': 2.3819256646753313e-06, 'max_iter': 450, 'fit_intercept': True},
#     'SEC-002': {'epsilon': 1.3, 'alpha': 0.043570676782234655, 'max_iter': 600, 'fit_intercept': True},
#     'SEC-003': {'epsilon': 1.3, 'alpha': 5.002881133425486e-06, 'max_iter': 1550, 'fit_intercept': True},
#     'SEC-004': {'epsilon': 1.0, 'alpha': 0.002086668812396698, 'max_iter': 300, 'fit_intercept': True},
#     'SEC-005': {'epsilon': 1.4, 'alpha': 0.0001800366193826709, 'max_iter': 1350, 'fit_intercept': True},
#     'SEC-006': {'epsilon': 2.2, 'alpha': 4.514009372796933e-05, 'max_iter': 1250, 'fit_intercept': True},
# }
#
# 🎯 RECOMMENDED DEFAULT PARAMETERS:
# DEFAULT_HUBER_PARAMS = {
#     'epsilon': 1.6167,
#     'alpha': 0.0001,  # Median of log-uniform distribution
#     'max_iter': 916,
#     'fit_intercept': True
# }
#
# 📁 FILES SAVED:
#    - huber_regression_tuning_results.csv: Detailed tuning results
#    - huber_regression_comparison.csv: Tuned vs default comparison
#    - optimized_huber_params.json: Parameters for main code
#
# 🎉 HUBER REGRESSION TUNING COMPLETED!
# ✅ Tuned 6 sections successfully
#
# 📋 HOW TO INTEGRATE WITH YOUR MAIN CODE:
# ==================================================
# 1. Copy the OPTIMIZED_HUBER_PARAMS dictionary above
# 2. In your main code, replace the HuberRegressor creation with:
#
# # In Block 3 of your main code:
# def get_huber_params(section_id):
#     return OPTIMIZED_HUBER_PARAMS.get(section_id, DEFAULT_HUBER_PARAMS)
#
# # Replace your model creation:
# for section in working_train['section_id'].unique():
#     section_data = working_train[working_train['section_id'] == section]
#     if len(section_data) > 30:
#         X = section_data[['total_task_time_minutes']].values
#         y = section_data['employees_on_duty'].values
#
#         # Get optimized parameters
#         params = get_huber_params(section)
#
#         # Build optimized model
#         model = HuberRegressor(**params)
#         model.fit(X, y)
#         # ... rest of your code
#
#
# ✅ Ready to boost your regression performance!
